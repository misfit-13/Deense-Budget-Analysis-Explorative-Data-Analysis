# %% [markdown]
# # DEFENSE BUDGET ANALYSIS OF VARIOUS STRATEGIC REGIONS OF THE WORLD

# %% [markdown]
# ## NAMAN JOSHI
#
# ## ROLL NUMBER: 18152
#
# ## DEPARTMENT OF PHYSICS

# %% [markdown]
# # Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing Data From Device

# %% [markdown]
# 1. Military Expediture of Countries (1960-2020)
# 2. GDP of Countries (1960-2020)
# 3. % of GDP spent on Research and Development (1960-2020)
# 4. % of GDP spent on Defense (1960-2020)

# %%
mil_ex = pd.read_csv("G:\IISERB\SEM 7\Py_Prog\Final_report\mil_exp.csv", sep = '\t')
mil_ex
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                          Indicator Name  Indicator Code        1960  \
# 0    Military expenditure (current USD)  MS.MIL.XPND.CD         NaN
# 1    Military expenditure (current USD)  MS.MIL.XPND.CD         NaN
# 2    Military expenditure (current USD)  MS.MIL.XPND.CD         NaN
# 3    Military expenditure (current USD)  MS.MIL.XPND.CD         NaN
# ...

# %%
gdp = pd.read_csv("G:\IISERB\SEM 7\Py_Prog\Final_report\GDP_cntry.csv", sep ='\t')
gdp
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  GDP (current US$)
# 1    Africa Eastern and Southern          AFE  GDP (current US$)
# 2                    Afghanistan          AFG  GDP (current US$)
# 3     Africa Western and Central          AFW  GDP (current US$)
# 4                         Angola          AGO  GDP (current US$)
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  GDP (current US$)
# 262                  Yemen, Rep.          YEM  GDP (current US$)
# 263                 South Africa          ZAF  GDP (current US$)
# 264                       Zambia          ZMB  GDP (current US$)
# 265                     Zimbabwe          ZWE  GDP (current US$)
#
#      Indicator Code          1960          1961          1962          1963  \
# 0    NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# ...

# %%
def_perc_gdp = pd.read_csv("G:\IISERB\SEM 7\Py_Prog\Final_report\def_perc_gdp.csv", sep = '\t')
def_perc_gdp
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                       Indicator Name     Indicator Code      1960      1961  \
# 0    Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS       NaN       NaN
# 1    Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS       NaN       NaN
# 2    Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS       NaN       NaN
# 3    Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS       NaN       NaN
# ...

# %%
gdp_pc = pd.read_csv("G:\IISERB\SEM 7\Py_Prog\Final_report\GDP.csv")
gdp_pc
# Out:
#                     Country Name Country Code                Indicator Name  \
# 0                          Aruba          ABW  GDP per capita (current US$)
# 1    Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                    Afghanistan          AFG  GDP per capita (current US$)
# 3     Africa Western and Central          AFW  GDP per capita (current US$)
# 4                         Angola          AGO  GDP per capita (current US$)
# ..                           ...          ...                           ...
# 261                       Kosovo          XKX  GDP per capita (current US$)
# 262                  Yemen, Rep.          YEM  GDP per capita (current US$)
# 263                 South Africa          ZAF  GDP per capita (current US$)
# 264                       Zambia          ZMB  GDP per capita (current US$)
# 265                     Zimbabwe          ZWE  GDP per capita (current US$)
#
# ...

# %%
RnD_ex = pd.read_csv("G:\IISERB\SEM 7\Py_Prog\Final_report\gdp_rnd.csv", sep = '\t')
RnD_ex
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0    Research and development expenditure (% of GDP)  GB.XPD.RSDV.GD.ZS   NaN
# 1    Research and development expenditure (% of GDP)  GB.XPD.RSDV.GD.ZS   NaN
# 2    Research and development expenditure (% of GDP)  GB.XPD.RSDV.GD.ZS   NaN
# 3    Research and development expenditure (% of GDP)  GB.XPD.RSDV.GD.ZS   NaN
# ...

# %% [markdown]
# # Dropping Unwanted Columns

# %%
mil_ex.drop(['Indicator Name', 'Indicator Code'], axis=1, inplace=True)
mil_ex
# Out:
#                     Country Name Country Code        1960          1961  \
# 0                          Aruba          ABW         NaN           NaN
# 1    Africa Eastern and Southern          AFE         NaN           NaN
# 2                    Afghanistan          AFG         NaN           NaN
# 3     Africa Western and Central          AFW         NaN  6.573052e+07
# 4                         Angola          AGO         NaN           NaN
# ..                           ...          ...         ...           ...
# 261                       Kosovo          XKX         NaN           NaN
# 262                  Yemen, Rep.          YEM         NaN           NaN
# 263                 South Africa          ZAF  69999972.0  1.137500e+08
# 264                       Zambia          ZMB         NaN           NaN
# 265                     Zimbabwe          ZWE         NaN           NaN
#
#              1962         1963         1964         1965         1966  \
# ...

# %%
gdp.drop(['Indicator Name', 'Indicator Code'], axis=1, inplace=True)
gdp
# Out:
#                     Country Name Country Code          1960          1961  \
# 0                          Aruba          ABW           NaN           NaN
# 1    Africa Eastern and Southern          AFE  1.934248e+10  1.975349e+10
# 2                    Afghanistan          AFG  5.377778e+08  5.488889e+08
# 3     Africa Western and Central          AFW  1.040732e+10  1.113130e+10
# 4                         Angola          AGO           NaN           NaN
# ..                           ...          ...           ...           ...
# 261                       Kosovo          XKX           NaN           NaN
# 262                  Yemen, Rep.          YEM           NaN           NaN
# 263                 South Africa          ZAF  7.575397e+09  7.972997e+09
# 264                       Zambia          ZMB  7.130000e+08  6.962857e+08
# 265                     Zimbabwe          ZWE  1.052990e+09  1.096647e+09
#
#              1962          1963          1964          1965          1966  \
# ...

# %%
def_perc_gdp.drop(['Indicator Name', 'Indicator Code'], axis=1, inplace=True)
def_perc_gdp
# Out:
#                     Country Name Country Code      1960      1961      1962  \
# 0                          Aruba          ABW       NaN       NaN       NaN
# 1    Africa Eastern and Southern          AFE       NaN       NaN       NaN
# 2                    Afghanistan          AFG       NaN       NaN       NaN
# 3     Africa Western and Central          AFW       NaN       NaN  1.319932
# 4                         Angola          AGO       NaN       NaN       NaN
# ..                           ...          ...       ...       ...       ...
# 261                       Kosovo          XKX       NaN       NaN       NaN
# 262                  Yemen, Rep.          YEM       NaN       NaN       NaN
# 263                 South Africa          ZAF  0.950977  1.467849  2.254837
# 264                       Zambia          ZMB       NaN       NaN       NaN
# 265                     Zimbabwe          ZWE       NaN       NaN       NaN
#
# ...

# %%
gdp_pc.drop(['Indicator Name', 'Indicator Code'], axis=1, inplace=True)
gdp_pc
# Out:
#                     Country Name Country Code        1960        1961  \
# 0                          Aruba          ABW         NaN         NaN
# 1    Africa Eastern and Southern          AFE  147.836769  147.238537
# 2                    Afghanistan          AFG   59.773234   59.860900
# 3     Africa Western and Central          AFW  107.963779  113.114697
# 4                         Angola          AGO         NaN         NaN
# ..                           ...          ...         ...         ...
# 261                       Kosovo          XKX         NaN         NaN
# 262                  Yemen, Rep.          YEM         NaN         NaN
# 263                 South Africa          ZAF  443.009920  454.962013
# 264                       Zambia          ZMB  232.188565  220.042067
# 265                     Zimbabwe          ZWE  278.813847  280.828663
#
#            1962        1963        1964        1965        1966        1967  \
# ...

# %%
RnD_ex.drop(['Indicator Name', 'Indicator Code'], axis=1, inplace=True)
RnD_ex
# Out:
#                     Country Name Country Code  1960  1961  1962  1963  1964  \
# 0                          Aruba          ABW   NaN   NaN   NaN   NaN   NaN
# 1    Africa Eastern and Southern          AFE   NaN   NaN   NaN   NaN   NaN
# 2                    Afghanistan          AFG   NaN   NaN   NaN   NaN   NaN
# 3     Africa Western and Central          AFW   NaN   NaN   NaN   NaN   NaN
# 4                         Angola          AGO   NaN   NaN   NaN   NaN   NaN
# ..                           ...          ...   ...   ...   ...   ...   ...
# 261                       Kosovo          XKX   NaN   NaN   NaN   NaN   NaN
# 262                  Yemen, Rep.          YEM   NaN   NaN   NaN   NaN   NaN
# 263                 South Africa          ZAF   NaN   NaN   NaN   NaN   NaN
# 264                       Zambia          ZMB   NaN   NaN   NaN   NaN   NaN
# 265                     Zimbabwe          ZWE   NaN   NaN   NaN   NaN   NaN
#
# ...

# %% [markdown]
# # Dropping Countries That Haven't Provided Data

# %%
absnt_list = ['Aruba', 'Andorra', 'American Samoa', 'Antigua and Barbuda', 'Bahamas, The', 'Bermuda', 'Bhutan', 'Barbados', 'Channel Island', 'Comoros', 'Costa Rica', 'Curacao', 'Cayman Island', 'Dominica', 'Eritrea', 'Faroe Islands', 'Micronesia, Fed. Sts.', 'Gibraltar', 'Grenada', 'Greenland', 'Guam', 'Hong Kong SAR, China', 'Isle of Man', 'Not Classified', 'Iceland', 'Kiribati', 'St. kitts and Nevis', 'Lao PDR', 'St. Lucia', 'Liechtenstein', 'Macao SAR, China', 'St. Martin (French Part)', 'Maldives', 'Marshall Islands', 'Northern Mariana Islands', 'New Caledonia', 'Nauru', 'Panama', 'Palau', 'Puerto Rico', 'West Bank and Gaza', 'Pacific island small states', 'French Polynesia', 'Solomon Islands', 'San Marino', 'Sao Tome and Pricipe', 'Suriname', 'Sint Maarten (Dutch Part)', 'Syrian Arab Republic', 'Turks and Caicos Islands', 'Turkmenistan', 'Tonga', 'Tuvalu', 'St. Vincent and the Grenadines', 'British Virgin Islands', 'Virgin Islands (U.S.)', 'Vanuatu', 'Samoa']
#absnt_list

# %%
for cont in absnt_list:
    mil_ex.drop(mil_ex[mil_ex['Country Name'] == cont].index, inplace = True)
    
#mil_ex.head(10)

# %%
for cont in absnt_list:
    gdp.drop(gdp[gdp['Country Name'] == cont].index, inplace = True)
    
#gdp_df.head(10)

# %%
for cont in absnt_list:
    def_perc_gdp.drop(def_perc_gdp[def_perc_gdp['Country Name'] == cont].index, inplace = True)
    
#def_perc_gdp.head(10)

# %%
for cont in absnt_list:
    gdp_pc.drop(gdp_pc[gdp_pc['Country Name'] == cont].index, inplace = True)
    
#gdp_df.head(10)

# %%
for cont in absnt_list:
    RnD_ex.drop(RnD_ex[RnD_ex['Country Name'] == cont].index, inplace = True)
    
#RnD_ex.head(10)

# %%
years = np.arange(1960, 2021, 1)
years
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020])

# %%
year_str = [str(i) for i in years]
#year_str

# %% [markdown]
# # Members of UN Security council

# %% [markdown]
# ## Taking Sum of Various Data for Last 10 Years

# %%
mil_ex_UN = mil_ex[(mil_ex['Country Code'].isin(['USA', 'GBR', 'FRA', 'CHN', 'RUS']))]
mil_ex_UN['sum_10_yrs'] = (mil_ex_UN['2011'] + mil_ex_UN['2012'] + mil_ex_UN['2013'] + mil_ex_UN['2014'] + mil_ex_UN['2015'])
                          
gdp_UN = gdp[(gdp['Country Code'].isin(['USA', 'GBR', 'FRA', 'CHN', 'RUS']))]
gdp_UN['sum_10_yrs'] = (gdp_UN['2011'] + gdp_UN['2012'] + gdp_UN['2013'] + gdp_UN['2014'] + gdp_UN['2015'])

df_gdp_UN = def_perc_gdp[(def_perc_gdp['Country Code'].isin(['USA', 'GBR', 'FRA', 'CHN', 'RUS']))]
df_gdp_UN['sum_10_yrs'] = (df_gdp_UN['2011'] + df_gdp_UN['2012'] + df_gdp_UN['2013'] + df_gdp_UN['2014'] + df_gdp_UN['2015'])

gdp_pc_UN = gdp_pc[(gdp_pc['Country Code'].isin(['USA', 'GBR', 'FRA', 'CHN', 'RUS']))]
gdp_pc_UN['sum_10_yrs'] = (gdp_pc_UN['2011'] + gdp_pc_UN['2012'] + gdp_pc_UN['2013'] + gdp_pc_UN['2014'] + gdp_pc_UN['2015'])
                           
RnD_UN = RnD_ex[(RnD_ex['Country Code'].isin(['USA', 'GBR', 'FRA', 'CHN', 'RUS']))]
RnD_UN['sum_10_yrs'] = (RnD_UN['2011'] + RnD_UN['2012'] + RnD_UN['2013'] + RnD_UN['2014'] + RnD_UN['2015'])

# %% [markdown]
# ## Finding Decade-Wise Values Defense Expenditure

# %%
dec_list = ['60s', '70s', '80s', '90s', '00s', '10s']

yr_list = [1960, 1970, 1980, 1990, 2000, 2010]
add = 0

for i in range(6):
    for j in range(10):
        add += mil_ex[str(yr_list[i]+j)]
    
    mil_ex[str(dec_list[i])] = add
    add = 0

# %%
mil_ex_bp = mil_ex[['Country Code', '60s', '70s', '80s', '90s', '00s', '10s']]
mil_ex_bp_plot = mil_ex_bp[(mil_ex_bp['Country Code'].isin(['USA', 'GBR', 'FRA', 'CHN', 'RUS']))]
mil_ex_bp_plot
# Out:
#     Country Code           60s           70s           80s           90s  \
# 40           CHN           NaN           NaN           NaN  1.340662e+11
# 77           FRA  4.240734e+10  1.025458e+11  2.269606e+11  3.627156e+11
# 81           GBR  6.052688e+10  1.173379e+11  3.020647e+11  4.115983e+11
# 202          RUS           NaN           NaN           NaN           NaN
# 251          USA  6.285930e+11  9.448259e+11  2.513821e+12  3.040412e+12
#
#               00s           10s
# 40   4.819537e+11  1.800500e+12
# 77   4.227529e+11  5.052601e+11
# 81   5.719407e+11  6.043218e+11
# 202  2.858900e+11  7.128672e+11
# 251  5.007683e+12  6.879790e+12

# %% [markdown]
# ## Ploting the Defense Budget

# %%
plt.figure(figsize = (15, 10))

plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'USA', year_str].T/(10)**9, marker = '*', label = 'USA')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'GBR', year_str].T/(10)**9, marker = 'o', label = 'UK')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'FRA', year_str].T/(10)**9, marker = 'X', label = 'FRANCE')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'CHN', year_str].T/(10)**9, marker = '^', label = 'CHINA')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'RUS', year_str].T/(10)**9, marker = '+', label = 'RUSSIA')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Defence Budget (x10$\mathregular{^{9}}$ USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Bar Plot of Decade-wise Defense Budget

# %%
fig, ax = plt.subplots(figsize = (12, 8))

ax.bar(np.arange(len(mil_ex_bp_plot['Country Code'])), mil_ex_bp_plot['60s']/10**9, 0.1, label = "60s")
ax.bar(np.arange(len(mil_ex_bp_plot['Country Code'])) + 0.1, mil_ex_bp_plot['70s']/10**9, 0.2, label = "70s")
ax.bar(np.arange(len(mil_ex_bp_plot['Country Code'])) + 0.2, mil_ex_bp_plot['80s']/10**9, 0.2, label = "80s")
ax.bar(np.arange(len(mil_ex_bp_plot['Country Code'])) + 0.3, mil_ex_bp_plot['90s']/10**9, 0.2, label = "90s")
ax.bar(np.arange(len(mil_ex_bp_plot['Country Code'])) + 0.4, mil_ex_bp_plot['00s']/10**9, 0.2, label = "00s")
ax.bar(np.arange(len(mil_ex_bp_plot['Country Code'])) + 0.5, mil_ex_bp_plot['10s']/10**9, 0.2, label = "10s")


ax.set_ylabel('Absolute Numbers (x10$\mathregular{^{9}}$ USD)', fontsize = 15)
ax.set_xticks(np.arange(len(mil_ex_bp_plot['Country Code']))+ 0.2)
ax.set_xticklabels(mil_ex_bp_plot['Country Code'])
ax.set_xlabel('Country', fontsize = 15)
ax.set_title('Decadal Spending on defense budget\n', fontsize = 25)

ax.legend()
ax.grid()
#plt.savefig("norm_case_test_bar.jpg")
#plt.show()

# %% [markdown]
# ## Plot of GDP

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, gdp.loc[gdp['Country Code'] == 'USA', year_str].T/10**9, marker = '*', label = 'USA')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'GBR', year_str].T/10**9, marker = 'o', label = 'UK')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'FRA', year_str].T/10**9, marker = 'X', label = 'FRANCE')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'CHN', year_str].T/10**9, marker = '^', label = 'CHINA')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'RUS', year_str].T/10**9, marker = '+', label = 'RUSSIA')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Gross Domestic Product (x10$\mathregular{^{9}}$ USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Plot of GDP Per Capita

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'USA', year_str].T, marker = '*', label = 'USA')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'GBR', year_str].T, marker = 'o', label = 'UK')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'FRA', year_str].T, marker = 'X', label = 'FRANCE')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'CHN', year_str].T, marker = '^', label = 'CHINA')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'RUS', year_str].T, marker = '+', label = 'RUSSIA')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Gross Domestic Product (USD) Per Capita\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Plot of % of GDP spent on RnD

# %%
plt.figure(figsize = (15, 10))
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'USA', year_str].T[36:], marker = '*', label = 'USA')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'GBR', year_str].T[36:], marker = 'o', label = 'UK')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'FRA', year_str].T[36:], marker = 'X', label = 'FRANCE')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'CHN', year_str].T[36:], marker = '^', label = 'CHINA')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'RUS', year_str].T[36:], marker = '+', label = 'RUSSIA')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('% of GDP spent on Research & Development\n', fontsize = 18)


plt.xticks(np.arange(1995, 2021, 3))
plt.show()

# %% [markdown]
# ## Bar Plot for Per Capita Income and % of GDP Spent on Defense and RnD

# %%
plt.figure(figsize = (24, 10))

plt.subplot(1,3, 1)
plt.pie(gdp_pc_UN['sum_10_yrs']/10, labels = gdp_pc_UN['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("Average GDP Per Capita\n Members of UN Security Council", fontsize = 18)

#plt.savefig("tot_pie.jpg")

plt.subplot(1, 3, 2)
plt.pie(df_gdp_UN['sum_10_yrs'], labels = df_gdp_UN['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("% of GDP spent on Defense by\n Members of UN Security Council", fontsize = 18)

#plt.savefig("tot_pie.jpg")


plt.subplot(1, 3, 3)
plt.pie(RnD_UN['sum_10_yrs']/10, labels = RnD_UN['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("Average % Spending on RnD for \nmembers of UN Security Council", fontsize = 18)
plt.show()
#plt.savefig("tot_pie.jpg")

# %% [markdown]
# # Members of Quad

# %% [markdown]
# ## Taking Sum of Various Data for Last 10 Years

# %%
mil_ex_QUAD = mil_ex[(mil_ex['Country Code'].isin(['USA', 'AUS', 'IND', 'JPN']))]
mil_ex_QUAD['sum_10_yrs'] = (mil_ex_QUAD['2011'] + mil_ex_QUAD['2012'] + mil_ex_QUAD['2013'] + mil_ex_QUAD['2014'] + mil_ex_QUAD['2015'])
                          
gdp_QUAD = gdp[(gdp['Country Code'].isin(['USA', 'AUS', 'IND', 'JPN']))]
gdp_QUAD['sum_10_yrs'] = (gdp_QUAD['2011'] + gdp_QUAD['2012'] + gdp_QUAD['2013'] + gdp_QUAD['2014'] + gdp_QUAD['2015'])

df_gdp_QUAD = def_perc_gdp[(def_perc_gdp['Country Code'].isin(['USA', 'AUS', 'IND', 'JPN']))]
df_gdp_QUAD['sum_10_yrs'] = (df_gdp_QUAD['2011'] + df_gdp_QUAD['2012'] + df_gdp_QUAD['2013'] + df_gdp_QUAD['2014'] + df_gdp_QUAD['2015'])

gdp_pc_QUAD = gdp_pc[(gdp_pc['Country Code'].isin(['USA', 'AUS', 'IND', 'JPN']))]
gdp_pc_QUAD['sum_10_yrs'] = (gdp_pc_QUAD['2011'] + gdp_pc_QUAD['2012'] + gdp_pc_QUAD['2013'] + gdp_pc_QUAD['2014'] + gdp_pc_QUAD['2015'])
                           
RnD_QUAD = RnD_ex[(RnD_ex['Country Code'].isin(['USA', 'AUS', 'IND', 'JPN']))]
RnD_QUAD['sum_10_yrs'] = (RnD_QUAD['2011'] + RnD_QUAD['2012'] + RnD_QUAD['2013'] + RnD_QUAD['2014'] + RnD_QUAD['2015'])
RnD_QUAD.fillna(0, inplace=True)
#RnD_QUAD

# %% [markdown]
# ## Ploting the Defense Budget

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'USA', year_str].T/(10)**9, marker = '*', label = 'USA')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'AUS', year_str].T/(10)**9, marker = 'o', label = 'AUSTRALIA')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'IND', year_str].T/(10)**9, marker = 'X', label = 'INDIA')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'JPN', year_str].T/(10)**9, marker = '^', label = 'JAPAN')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Defence Budget (x10$\mathregular{^{9}}$ USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Bar Plot of Decade-wise Defense Budget

# %%
mil_ex_bp_QUAD = mil_ex[['Country Code', '60s', '70s', '80s', '90s', '00s', '10s']]
mil_ex_bp_plot_QUAD = mil_ex_bp[(mil_ex_bp['Country Code'].isin(['USA', 'AUS', 'IND', 'JPN']))]
#mil_ex_bp_plot

fig, ax = plt.subplots(figsize = (12, 8))

ax.bar(np.arange(len(mil_ex_bp_plot_QUAD['Country Code'])), mil_ex_bp_plot_QUAD['60s']/10**9, 0.2, label = "60s")
ax.bar(np.arange(len(mil_ex_bp_plot_QUAD['Country Code'])) + 0.1, mil_ex_bp_plot_QUAD['70s']/10**9, 0.2, label = "70s")
ax.bar(np.arange(len(mil_ex_bp_plot_QUAD['Country Code'])) + 0.2, mil_ex_bp_plot_QUAD['80s']/10**9, 0.2, label = "80s")
ax.bar(np.arange(len(mil_ex_bp_plot_QUAD['Country Code'])) + 0.3, mil_ex_bp_plot_QUAD['90s']/10**9, 0.2, label = "90s")
ax.bar(np.arange(len(mil_ex_bp_plot_QUAD['Country Code'])) + 0.4, mil_ex_bp_plot_QUAD['00s']/10**9, 0.2, label = "00s")
ax.bar(np.arange(len(mil_ex_bp_plot_QUAD['Country Code'])) + 0.5, mil_ex_bp_plot_QUAD['10s']/10**9, 0.2, label = "10s")


ax.set_ylabel('Absolute Numbers (x10$\mathregular{^{9}}$ USD)', fontsize = 15)
ax.set_xticks(np.arange(len(mil_ex_bp_plot_QUAD['Country Code']))+ 0.2)
ax.set_xticklabels(mil_ex_bp_plot_QUAD['Country Code'])
ax.set_xlabel('Country', fontsize = 15)
ax.set_title('Decadal Spending on defense budget\n', fontsize = 25)

ax.legend()
ax.grid()
#plt.savefig("norm_case_test_bar.jpg")
#plt.show()

# %% [markdown]
# ## Plot of GDP

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, gdp.loc[gdp['Country Code'] == 'USA', year_str].T/10**9, marker = '*', label = 'USA')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'AUS', year_str].T/10**9, marker = 'o', label = 'AUSTRALIA')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'IND', year_str].T/10**9, marker = 'X', label = 'INDIA')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'JPN', year_str].T/10**9, marker = '^', label = 'JAPAN')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Gross Domestic Product (x10$\mathregular{^{9}}$ USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Plot of GDP Per Capita

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'USA', year_str].T, marker = '*', label = 'USA')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'AUS', year_str].T, marker = 'o', label = 'AUSTRALIA')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'IND', year_str].T, marker = 'X', label = 'INDIA')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'JPN', year_str].T, marker = '^', label = 'JAPAN')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Gross Domestic Product (USD) Per Capita\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Plot of % of GDP spent on RnD

# %%
plt.figure(figsize = (15, 10))
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'USA', year_str].T[36:], marker = '*', label = 'USA')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'AUS', year_str].T[36:], marker = 'o', label = 'AUSTRALIA')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'IND', year_str].T[36:], marker = 'X', label = 'INDIA')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'JPN', year_str].T[36:], marker = '^', label = 'JAPAN')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('% of GDP spent on Research & Development\n', fontsize = 18)

plt.xticks(np.arange(1995, 2021, 3))
plt.show()

# %% [markdown]
# ## Bar Plot for Per Capita Income and % of GDP Spent on Defense and RnD

# %%
plt.figure(figsize = (24, 10))

plt.subplot(1,3, 1)
plt.pie(gdp_pc_QUAD['sum_10_yrs']/10, labels = gdp_pc_QUAD['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("Average GDP Per Capita\n members of QUAD", fontsize = 22)

#plt.savefig("tot_pie.jpg")

plt.subplot(1, 3, 2)
plt.pie(df_gdp_QUAD['sum_10_yrs'], labels = df_gdp_QUAD['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("% of GDP spent on Defense by\n members of QUAD", fontsize = 22)

#plt.savefig("tot_pie.jpg")


plt.subplot(1, 3, 3)
plt.pie(RnD_QUAD['sum_10_yrs']/10, labels = RnD_QUAD['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("Average % Spending on RnD for \nmembers of QUAD", fontsize = 22)
plt.show()
#plt.savefig("tot_pie.jpg")

# %% [markdown]
# # Israel And The Middle East Problem

# %% [markdown]
# ## Taking Sum of Various Data for Last 10 Years

# %%
mil_ex_ME = mil_ex[(mil_ex['Country Code'].isin(['ISR', 'SAU', 'TUR', 'IRN']))]
mil_ex_ME['sum_10_yrs'] = (mil_ex_ME['2011'] + mil_ex_ME['2012'] + mil_ex_ME['2013'] + mil_ex_ME['2014'] + mil_ex_ME['2015'])
                          
gdp_ME = gdp[(gdp['Country Code'].isin(['ISR', 'SAU', 'TUR', 'IRN']))]
gdp_ME['sum_10_yrs'] = (gdp_ME['2011'] + gdp_ME['2012'] + gdp_ME['2013'] + gdp_ME['2014'] + gdp_ME['2015'])

df_gdp_ME = def_perc_gdp[(def_perc_gdp['Country Code'].isin(['ISR', 'SAU', 'TUR', 'IRN']))]
df_gdp_ME['sum_10_yrs'] = (df_gdp_ME['2011'] + df_gdp_ME['2012'] + df_gdp_ME['2013'] + df_gdp_ME['2014'] + df_gdp_ME['2015'])

gdp_pc_ME = gdp_pc[(gdp_pc['Country Code'].isin(['ISR', 'SAU', 'TUR', 'IRN']))]
gdp_pc_ME['sum_10_yrs'] = (gdp_pc_ME['2011'] + gdp_pc_ME['2012'] + gdp_pc_ME['2013'] + gdp_pc_ME['2014'] + gdp_pc_ME['2015'])
                           
RnD_ME = RnD_ex[(RnD_ex['Country Code'].isin(['ISR', 'SAU', 'TUR', 'IRN']))]
RnD_ME['sum_10_yrs'] = (RnD_ME['2011'] + RnD_ME['2012'] + RnD_ME['2013'] + RnD_ME['2014'] + RnD_ME['2015'])
RnD_ME.fillna(0, inplace = True)

# %% [markdown]
# ## Ploting the Defense Budget

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'ISR', year_str].T/(10)**8, marker = '*', label = 'ISRAEL')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'SAU', year_str].T/(10)**8, marker = 'o', label = 'SAUDI ARABIA')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'TUR', year_str].T/(10)**8, marker = 'X', label = 'TURKEY')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'IRN', year_str].T/(10)**8, marker = '^', label = 'IRAN')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Defence Budget (x10$\mathregular{^{8}}$ USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Bar Plot of Decade-wise Defense Budget

# %%
mil_ex_bp_plot_ME = mil_ex_bp[(mil_ex_bp['Country Code'].isin(['ISR', 'SAU', 'TUR', 'IRN']))]
#mil_ex_bp_plot

fig, ax = plt.subplots(figsize = (12, 8))

ax.bar(np.arange(len(mil_ex_bp_plot_ME['Country Code'])), mil_ex_bp_plot_ME['60s']/10**9, 0.2, label = "60s")
ax.bar(np.arange(len(mil_ex_bp_plot_ME['Country Code'])) + 0.1, mil_ex_bp_plot_ME['70s']/10**9, 0.2, label = "70s")
ax.bar(np.arange(len(mil_ex_bp_plot_ME['Country Code'])) + 0.2, mil_ex_bp_plot_ME['80s']/10**9, 0.2, label = "80s")
ax.bar(np.arange(len(mil_ex_bp_plot_ME['Country Code'])) + 0.3, mil_ex_bp_plot_ME['90s']/10**9, 0.2, label = "90s")
ax.bar(np.arange(len(mil_ex_bp_plot_ME['Country Code'])) + 0.4, mil_ex_bp_plot_ME['00s']/10**9, 0.2, label = "00s")
ax.bar(np.arange(len(mil_ex_bp_plot_ME['Country Code'])) + 0.5, mil_ex_bp_plot_ME['10s']/10**9, 0.2, label = "10s")


ax.set_ylabel('Absolute Numbers (x10$\mathregular{^{9}}$ USD)', fontsize = 15)
ax.set_xticks(np.arange(len(mil_ex_bp_plot_ME['Country Code']))+ 0.2)
ax.set_xticklabels(mil_ex_bp_plot_ME['Country Code'])
ax.set_xlabel('Country', fontsize = 15)
ax.set_title('Decadal Spending on defense budget\n', fontsize = 25)

ax.legend()
ax.grid()
#plt.savefig("norm_case_test_bar.jpg")
#plt.show()

# %% [markdown]
# ## Plot of GDP

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, gdp.loc[gdp['Country Code'] == 'ISR', year_str].T/10**9, marker = '*', label = 'ISRAEL')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'SAU', year_str].T/10**9, marker = 'o', label = 'SAUDI ARABIA')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'TUR', year_str].T/10**9, marker = 'X', label = 'TURKEY')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'IRN', year_str].T/10**9, marker = '^', label = 'IRAN')


plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Gross Domestic Product (x10$\mathregular{^{9}}$ USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Plot of GDP Per Capita

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'ISR', year_str].T, marker = '*', label = 'ISRAEL')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'SAU', year_str].T, marker = 'o', label = 'SAUDI ARABIA')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'TUR', year_str].T, marker = 'X', label = 'TURKEY')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'IRN', year_str].T, marker = '^', label = 'IRAN')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Gross Domestic Product Per Capita(USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Plot of % of GDP spent on RnD

# %%
plt.figure(figsize = (15, 10))
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'ISR', year_str].T[36:], marker = '*', label = 'ISRAEL')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'SAU', year_str].T[36:], marker = 'o', label = 'SAUDI ARABIA')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'TUR', year_str].T[36:], marker = 'X', label = 'TURKEY')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'IRN', year_str].T[36:], marker = '^', label = 'IRAN')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('% of GDP spent on Research & Development\n', fontsize = 18)

plt.xticks(np.arange(1995, 2021, 3))
plt.show()

# %% [markdown]
# ## Bar Plot for Per Capita Income and % of GDP Spent on Defense and RnD

# %%
plt.figure(figsize = (24, 10))

plt.subplot(1,3, 1)
plt.pie(gdp_pc_ME['sum_10_yrs']/10, labels = gdp_pc_ME['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("Average GDP Per Capita\nCountries of Middle-East", fontsize = 22)

#plt.savefig("tot_pie.jpg")

plt.subplot(1, 3, 2)
plt.pie(df_gdp_ME['sum_10_yrs'], labels = df_gdp_ME['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("% of GDP spent on Defense \nby Countries of Middle-East", fontsize = 22)

#plt.savefig("tot_pie.jpg")


plt.subplot(1, 3, 3)
plt.pie(RnD_ME['sum_10_yrs']/10, labels = RnD_ME['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("Average % Spending on RnD \nfor Countries of Middle-East", fontsize = 22)
plt.show()
#plt.savefig("tot_pie.jpg")

# %% [markdown]
# # Korean Peninsula

# %% [markdown]
# ## Taking Sum of Various Data for Last 10 Years

# %%
mil_ex_KP = mil_ex[(mil_ex['Country Code'].isin(['KOR', 'PRK', 'CHN', 'JPN']))]
mil_ex_KP['sum_10_yrs'] = (mil_ex_KP['2011'] + mil_ex_KP['2012'] + mil_ex_KP['2013'] + mil_ex_KP['2014'] + mil_ex_KP['2015'])
                          
gdp_KP = gdp[(gdp['Country Code'].isin(['KOR', 'PRK', 'CHN', 'JPN']))]
gdp_KP['sum_10_yrs'] = (gdp_KP['2011'] + gdp_KP['2012'] + gdp_KP['2013'] + gdp_KP['2014'] + gdp_KP['2015'])

df_gdp_KP = def_perc_gdp[(def_perc_gdp['Country Code'].isin(['KOR', 'PRK', 'CHN', 'JPN']))]
df_gdp_KP['sum_10_yrs'] = (df_gdp_KP['2011'] + df_gdp_KP['2012'] + df_gdp_KP['2013'] + df_gdp_KP['2014'] + df_gdp_KP['2015'])

gdp_pc_KP = gdp_pc[(gdp_pc['Country Code'].isin(['KOR', 'PRK', 'CHN', 'JPN']))]
gdp_pc_KP['sum_10_yrs'] = (gdp_pc_KP['2011'] + gdp_pc_KP['2012'] + gdp_pc_KP['2013'] + gdp_pc_KP['2014'] + gdp_pc_KP['2015'])
                           
RnD_KP = RnD_ex[(RnD_ex['Country Code'].isin(['KOR', 'PRK', 'CHN', 'JPN']))]
RnD_KP['sum_10_yrs'] = (RnD_KP['2011'] + RnD_KP['2012'] + RnD_KP['2013'] + RnD_KP['2014'] + RnD_KP['2015'])

# %% [markdown]
# ## Ploting the Defense Budget

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'KOR', year_str].T/(10)**8, marker = '*', label = 'KOREA')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'PRK', year_str].T/(10)**8, marker = '*', label = 'NORTH KOREA')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'JPN', year_str].T/(10)**8, marker = 'o', label = 'JAPAN')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'CHN', year_str].T/(10)**8, marker = 'o', label = 'CHINA')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Defence Budget (x10$\mathregular{^{8}}$ USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Bar Plot of Decade-wise Defense Budget

# %%
mil_ex_bp_plot_KP = mil_ex_bp[(mil_ex_bp['Country Code'].isin(['KOR', 'PRK', 'JPN', 'CHN']))]
#mil_ex_bp_plot

fig, ax = plt.subplots(figsize = (12, 8))

ax.bar(np.arange(len(mil_ex_bp_plot_KP['Country Code'])), mil_ex_bp_plot_KP['60s']/10**9, 0.2, label = "60s")
ax.bar(np.arange(len(mil_ex_bp_plot_KP['Country Code'])) + 0.1, mil_ex_bp_plot_KP['70s']/10**9, 0.2, label = "70s")
ax.bar(np.arange(len(mil_ex_bp_plot_KP['Country Code'])) + 0.2, mil_ex_bp_plot_KP['80s']/10**9, 0.2, label = "80s")
ax.bar(np.arange(len(mil_ex_bp_plot_KP['Country Code'])) + 0.3, mil_ex_bp_plot_KP['90s']/10**9, 0.2, label = "90s")
ax.bar(np.arange(len(mil_ex_bp_plot_KP['Country Code'])) + 0.4, mil_ex_bp_plot_KP['00s']/10**9, 0.2, label = "00s")
ax.bar(np.arange(len(mil_ex_bp_plot_KP['Country Code'])) + 0.5, mil_ex_bp_plot_KP['10s']/10**9, 0.2, label = "10s")


ax.set_ylabel('Absolute Numbers (x10$\mathregular{^{9}}$ USD)', fontsize = 15)
ax.set_xticks(np.arange(len(mil_ex_bp_plot_KP['Country Code']))+ 0.2)
ax.set_xticklabels(mil_ex_bp_plot_KP['Country Code'])
ax.set_xlabel('Country', fontsize = 15)
ax.set_title('Decadal Spending on defense budget\n', fontsize = 25)

ax.legend()
ax.grid()
#plt.savefig("norm_case_test_bar.jpg")
#plt.show()

# %% [markdown]
# ## Plot of GDP

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, gdp.loc[gdp['Country Code'] == 'KOR', year_str].T/10**9, marker = '*', label = 'SOUTH KOREA')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'PRK', year_str].T/10**9, marker = '*', label = 'NORTH KOREA')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'JPN', year_str].T/10**9, marker = 'o', label = 'JAPAN')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'CHN', year_str].T/10**9, marker = 'o', label = 'CHINA')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Gross Domestic Product (x10$\mathregular{^{9}}$ USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Plot of GDP Per Capita

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'KOR', year_str].T, marker = '*', label = 'SOUTH KOREA')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'PRK', year_str].T, marker = '*', label = 'NORTH KOREA')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'JPN', year_str].T, marker = 'o', label = 'JAPAN')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'CHN', year_str].T, marker = 'o', label = 'CHINA')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Gross Domestic Product Per Capita(USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Plot of % of GDP spent on RnD

# %%
plt.figure(figsize = (15, 10))
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'KOR', year_str].T[36:], marker = '*', label = 'SOUTH KOREA')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'PRK', year_str].T[36:], marker = '*', label = 'NORTH KOREA')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'JPN', year_str].T[36:], marker = 'X', label = 'JAPAN')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'CHN', year_str].T[36:], marker = 'X', label = 'CHINA')


plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('% of GDP spent on Research & Development\n', fontsize = 18)

plt.xticks(np.arange(1995, 2021, 3))
plt.show()

# %% [markdown]
# ## Bar Plot for Per Capita Income and % of GDP Spent on Defense and RnD

# %%
plt.figure(figsize = (24, 10))

plt.subplot(1,3, 1)
plt.pie(gdp_pc_KP['sum_10_yrs']/10, labels = gdp_pc_KP['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("Average GDP Per Capita\n countries of Korean Peninsula", fontsize = 22)

#plt.savefig("tot_pie.jpg")

plt.subplot(1, 3, 2)
plt.pie(df_gdp_KP['sum_10_yrs'], labels = df_gdp_KP['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("% of GDP spent on Defense by\n countries of Korean Peninsula", fontsize = 22)

#plt.savefig("tot_pie.jpg")


plt.subplot(1, 3, 3)
plt.pie(RnD_KP['sum_10_yrs']/10, labels = RnD_KP['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("Average % Spending on RnD for \ncountries of Korean Peninsula", fontsize = 22)
plt.show()
#plt.savefig("tot_pie.jpg")
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# # India and Pakistan

# %% [markdown]
# ## Taking Sum of Various Data for Last 10 Years

# %%
mil_ex_IP = mil_ex[(mil_ex['Country Code'].isin(['IND', 'PAK']))]
mil_ex_IP['sum_10_yrs'] = (mil_ex_IP['2011'] + mil_ex_IP['2012'] + mil_ex_IP['2013'] + mil_ex_IP['2014'] + mil_ex_IP['2015'])
                          
gdp_IP = gdp[(gdp['Country Code'].isin(['IND', 'PAK']))]
gdp_IP['sum_10_yrs'] = (gdp_IP['2011'] + gdp_IP['2012'] + gdp_IP['2013'] + gdp_IP['2014'] + gdp_IP['2015'])

df_gdp_IP = def_perc_gdp[(def_perc_gdp['Country Code'].isin(['IND', 'PAK']))]
df_gdp_IP['sum_10_yrs'] = (df_gdp_UN['2011'] + df_gdp_UN['2012'] + df_gdp_UN['2013'] + df_gdp_UN['2014'] + df_gdp_UN['2015'])
df_gdp_IP.fillna(0, inplace = True)

gdp_pc_IP = gdp_pc[(gdp_pc['Country Code'].isin(['IND', 'PAK']))]
gdp_pc_IP['sum_10_yrs'] = (gdp_pc_IP['2011'] + gdp_pc_IP['2012'] + gdp_pc_IP['2013'] + gdp_pc_IP['2014'] + gdp_pc_IP['2015'])
                           
RnD_IP = RnD_ex[(RnD_ex['Country Code'].isin(['IND', 'PAK']))]
RnD_IP['sum_10_yrs'] = (RnD_IP['2011'] + RnD_IP['2012'] + RnD_IP['2013'] + RnD_IP['2014'] + RnD_IP['2015'])
RnD_IP.fillna(0, inplace = True)

# %% [markdown]
# ## Ploting the Defense Budget

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'IND', year_str].T/(10)**8, marker = '*', label = 'INDIA')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'PAK', year_str].T/(10)**8, marker = 'o', label = 'PAKISTAN')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Defence Budget (x10$\mathregular{^{8}}$ USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Bar Plot of Decade-wise Defense Budget

# %%
mil_ex_bp_plot_IP = mil_ex_bp[(mil_ex_bp['Country Code'].isin(['IND', 'PAK']))]
#mil_ex_bp_plot

fig, ax = plt.subplots(figsize = (12, 8))

ax.bar(np.arange(len(mil_ex_bp_plot_IP['Country Code'])), mil_ex_bp_plot_IP['60s']/10**9, 0.2, label = "60s")
ax.bar(np.arange(len(mil_ex_bp_plot_IP['Country Code'])) + 0.1, mil_ex_bp_plot_IP['70s']/10**9, 0.2, label = "70s")
ax.bar(np.arange(len(mil_ex_bp_plot_IP['Country Code'])) + 0.2, mil_ex_bp_plot_IP['80s']/10**9, 0.2, label = "80s")
ax.bar(np.arange(len(mil_ex_bp_plot_IP['Country Code'])) + 0.3, mil_ex_bp_plot_IP['90s']/10**9, 0.2, label = "90s")
ax.bar(np.arange(len(mil_ex_bp_plot_IP['Country Code'])) + 0.4, mil_ex_bp_plot_IP['00s']/10**9, 0.2, label = "00s")
ax.bar(np.arange(len(mil_ex_bp_plot_IP['Country Code'])) + 0.5, mil_ex_bp_plot_IP['10s']/10**9, 0.2, label = "10s")


ax.set_ylabel('Absolute Numbers (x10$\mathregular{^{9}}$ USD)', fontsize = 15)
ax.set_xticks(np.arange(len(mil_ex_bp_plot_IP['Country Code']))+ 0.2)
ax.set_xticklabels(mil_ex_bp_plot_IP['Country Code'])
ax.set_xlabel('Country', fontsize = 15)
ax.set_title('Decadal Spending on defense budget\n', fontsize = 25)

ax.legend()
ax.grid()
#plt.savefig("norm_case_test_bar.jpg")
#plt.show()

# %% [markdown]
# ## Plot of GDP

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, gdp.loc[gdp['Country Code'] == 'IND', year_str].T/10**9, marker = '*', label = 'INDIA')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'PAK', year_str].T/10**9, marker = 'o', label = 'PAKISTAN')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Gross Domestic Product (x10$\mathregular{^{9}}$ USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Plot of GDP Per Capita

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'IND', year_str].T, marker = '*', label = 'INDIA')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'PAK', year_str].T, marker = 'o', label = 'PAKISTAN')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Gross Domestic Product Per Capita(USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Plot of % of GDP spent on RnD

# %%
plt.figure(figsize = (15, 10))
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'IND', year_str].T[36:], marker = '*', label = 'INDIA')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'PAK', year_str].T[36:], marker = 'X', label = 'PAKISTAN')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('% of GDP spent on Research & Development\n', fontsize = 18)

plt.xticks(np.arange(1995, 2021, 3))
plt.show()

# %% [markdown]
# ## Bar Plot for Per Capita Income and % of GDP Spent on Defense and RnD

# %%
plt.figure(figsize = (24, 10))

plt.subplot(1,3, 1)
plt.pie(gdp_pc_IP['sum_10_yrs']/10, labels = gdp_pc_IP['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("Average GDP Per Capita", fontsize = 22)

#plt.savefig("tot_pie.jpg")

plt.subplot(1, 3, 2)
plt.pie(df_gdp_IP['sum_10_yrs'], labels = df_gdp_IP['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("% of GDP spent on Defense by", fontsize = 22)

#plt.savefig("tot_pie.jpg")


plt.subplot(1, 3, 3)
plt.pie(RnD_IP['sum_10_yrs']/10, labels = RnD_IP['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("Average % Spending on RnD", fontsize = 22)
plt.show()
#plt.savefig("tot_pie.jpg")

# %% [markdown]
# # Income Based Classification

# %% [markdown]
# ## Taking Sum of Various Data for Last 10 Years

# %%
mil_ex_IBC = mil_ex[(mil_ex['Country Code'].isin(['HIC', 'UMC', 'LMC', 'LIC', 'HPC']))]
mil_ex_IBC['sum_10_yrs'] = (mil_ex_IBC['2011'] + mil_ex_IBC['2012'] + mil_ex_IBC['2013'] + mil_ex_IBC['2014'] + mil_ex_IBC['2015'])
                          
gdp_IBC = gdp[(gdp['Country Code'].isin(['HIC', 'UMC', 'LMC', 'LIC', 'HPC']))]
gdp_IBC['sum_10_yrs'] = (gdp_IBC['2011'] + gdp_IBC['2012'] + gdp_IBC['2013'] + gdp_IBC['2014'] + gdp_IBC['2015'])

df_gdp_IBC = def_perc_gdp[(def_perc_gdp['Country Code'].isin(['HIC', 'UMC', 'LMC', 'LIC', 'HPC']))]
df_gdp_IBC['sum_10_yrs'] = (df_gdp_IBC['2011'] + df_gdp_IBC['2012'] + df_gdp_IBC['2013'] + df_gdp_IBC['2014'] + df_gdp_IBC['2015'])

gdp_pc_IBC = gdp_pc[(gdp_pc['Country Code'].isin(['HIC', 'UMC', 'LMC', 'LIC', 'HPC']))]
gdp_pc_IBC['sum_10_yrs'] = (gdp_pc_IBC['2011'] + gdp_pc_IBC['2012'] + gdp_pc_IBC['2013'] + gdp_pc_IBC['2014'] + gdp_pc_IBC['2015'])
                           
RnD_IBC = RnD_ex[(RnD_ex['Country Code'].isin(['HIC', 'UMC', 'LMC', 'LIC', 'HPC']))]
RnD_IBC['sum_10_yrs'] = (RnD_IBC['2011'] + RnD_IBC['2012'] + RnD_IBC['2013'] + RnD_IBC['2014'] + RnD_IBC['2015'])
RnD_IBC.fillna(0, inplace = True)

# %% [markdown]
# ## Ploting the Defense Budget

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'HIC', year_str].T/(10)**8, marker = '^', label = 'High Income')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'UMC', year_str].T/(10)**8, marker = '*', label = 'Upper Middle')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'LMC', year_str].T/(10)**8, marker = 'o', label = 'Lower Middle')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'LIC', year_str].T/(10)**8, marker = '+', label = 'Low Income')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'HPC', year_str].T/(10)**8, marker = 'X', label = 'Heavily Debted Poor')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Defence Budget (x10$\mathregular{^{8}}$ USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Bar Plot of Decade-wise Defense Budget

# %%
mil_ex_bp_plot_IBC = mil_ex_bp[(mil_ex_bp['Country Code'].isin(['HIC', 'UMC', 'LMC', 'LIC', 'HPC']))]
#mil_ex_bp_plot

fig, ax = plt.subplots(figsize = (12, 8))

ax.bar(np.arange(len(mil_ex_bp_plot_IBC['Country Code'])), mil_ex_bp_plot_IBC['60s']/10**9, 0.2, label = "60s")
ax.bar(np.arange(len(mil_ex_bp_plot_IBC['Country Code'])) + 0.1, mil_ex_bp_plot_IBC['70s']/10**9, 0.2, label = "70s")
ax.bar(np.arange(len(mil_ex_bp_plot_IBC['Country Code'])) + 0.2, mil_ex_bp_plot_IBC['80s']/10**9, 0.2, label = "80s")
ax.bar(np.arange(len(mil_ex_bp_plot_IBC['Country Code'])) + 0.3, mil_ex_bp_plot_IBC['90s']/10**9, 0.2, label = "90s")
ax.bar(np.arange(len(mil_ex_bp_plot_IBC['Country Code'])) + 0.4, mil_ex_bp_plot_IBC['00s']/10**9, 0.2, label = "00s")
ax.bar(np.arange(len(mil_ex_bp_plot_IBC['Country Code'])) + 0.5, mil_ex_bp_plot_IBC['10s']/10**9, 0.2, label = "10s")


ax.set_ylabel('Absolute Numbers (x10$\mathregular{^{9}}$ USD)', fontsize = 15)
ax.set_xticks(np.arange(len(mil_ex_bp_plot_IBC['Country Code']))+ 0.2)
ax.set_xticklabels(mil_ex_bp_plot_IBC['Country Code'])
ax.set_xlabel('Country', fontsize = 15)
ax.set_title('Decadal Spending on defense budget\n', fontsize = 25)

ax.legend()
ax.grid()
#plt.savefig("norm_case_test_bar.jpg")
#plt.show()

# %% [markdown]
# ## Plot of GDP

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, gdp.loc[gdp['Country Code'] == 'HIC', year_str].T/10**9, marker = '*', label = 'High Income')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'UMC', year_str].T/10**9, marker = 'o', label = 'Upper Middle Income')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'LMC', year_str].T/10**9, marker = 'X', label = 'Lower Middle Income')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'LIC', year_str].T/10**9, marker = '+', label = 'Lower Income')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'HPC', year_str].T/10**9, marker = '^', label = 'Highly Debted Poor')


plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Gross Domestic Product (x10$\mathregular{^{9}}$ USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Plot of GDP Per Capita

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'HIC', year_str].T, marker = '*', label = 'High Income')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'UMC', year_str].T, marker = 'o', label = 'Upper Middle Income')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'LMC', year_str].T, marker = 'X', label = 'Lower Middle Income')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'LIC', year_str].T, marker = '+', label = 'Lower Income')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'HPC', year_str].T, marker = '^', label = 'Highly Debted Poor')


plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Gross Domestic Product Per Capita(USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Plot of % of GDP spent on RnD

# %%
plt.figure(figsize = (15, 10))
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'HIC', year_str].T[36:], marker = '*', label = 'High Income')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'UMC', year_str].T[36:], marker = 'o', label = 'Upper Middle Income')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'LMC', year_str].T[36:], marker = 'X', label = 'Low Middle Income')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'LIC', year_str].T[36:], marker = '^', label = 'Low Income')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'HPC', year_str].T[36:], marker = '^', label = 'Highlt debted Poor')


plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('% of GDP spent on Research & Development\n', fontsize = 18)

plt.xticks(np.arange(1995, 2021, 3))
plt.show()

# %% [markdown]
# ## Bar Plot for Per Capita Income and % of GDP Spent on Defense and RnD

# %%
plt.figure(figsize = (24, 10))

plt.subplot(1,3, 1)
plt.pie(gdp_pc_IBC['sum_10_yrs']/10, labels = gdp_pc_IBC['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("Average GDP Per Capita", fontsize = 22)

#plt.savefig("tot_pie.jpg")

plt.subplot(1, 3, 2)
plt.pie(df_gdp_IBC['sum_10_yrs'], labels = df_gdp_IBC['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("% of GDP spent on Defense", fontsize = 22)

#plt.savefig("tot_pie.jpg")


plt.subplot(1, 3, 3)
plt.pie(RnD_IBC['sum_10_yrs']/10, labels = RnD_IBC['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("Average % Spending on RnD", fontsize = 22)
plt.show()
#plt.savefig("tot_pie.jpg")

# %% [markdown]
# # BRICS

# %% [markdown]
# ## Taking Sum of Various Data for Last 10 Years

# %%
mil_ex_BRI = mil_ex[(mil_ex['Country Code'].isin(['BRA', 'RUS', 'IND', 'CHN', 'ZAF']))]
mil_ex_BRI['sum_10_yrs'] = (mil_ex_BRI['2011'] + mil_ex_BRI['2012'] + mil_ex_BRI['2013'] + mil_ex_BRI['2014'] + mil_ex_BRI['2015'])
                          
gdp_BRI = gdp[(gdp['Country Code'].isin(['BRA', 'RUS', 'IND', 'CHN', 'ZAF']))]
gdp_BRI['sum_10_yrs'] = (gdp_BRI['2011'] + gdp_BRI['2012'] + gdp_BRI['2013'] + gdp_BRI['2014'] + gdp_BRI['2015'])

df_gdp_BRI = def_perc_gdp[(def_perc_gdp['Country Code'].isin(['BRA', 'RUS', 'IND', 'CHN', 'ZAF']))]
df_gdp_BRI['sum_10_yrs'] = (df_gdp_BRI['2011'] + df_gdp_BRI['2012'] + df_gdp_BRI['2013'] + df_gdp_BRI['2014'] + df_gdp_BRI['2015'])

gdp_pc_BRI = gdp_pc[(gdp_pc['Country Code'].isin(['BRA', 'RUS', 'IND', 'CHN', 'ZAF']))]
gdp_pc_BRI['sum_10_yrs'] = (gdp_pc_BRI['2011'] + gdp_pc_BRI['2012'] + gdp_pc_BRI['2013'] + gdp_pc_BRI['2014'] + gdp_pc_BRI['2015'])
                           
RnD_BRI = RnD_ex[(RnD_ex['Country Code'].isin(['BRA', 'RUS', 'IND', 'CHN', 'ZAF']))]
RnD_BRI['sum_10_yrs'] = (RnD_BRI['2011'] + RnD_BRI['2012'] + RnD_BRI['2013'] + RnD_BRI['2014'] + RnD_BRI['2015'])

# %% [markdown]
# ## Ploting the Defense Budget

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'BRA', year_str].T/(10)**8, marker = '^', label = 'BRAZIL')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'RUS', year_str].T/(10)**8, marker = '*', label = 'RUSSIA')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'IND', year_str].T/(10)**8, marker = 'o', label = 'INDIA')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'CHN', year_str].T/(10)**8, marker = 'X', label = 'CHINA')
plt.plot(years, mil_ex.loc[mil_ex['Country Code'] == 'ZAF', year_str].T/(10)**8, marker = '+', label = 'SOUTH AFRICA')


plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Defence Budget (x10$\mathregular{^{8}}$ USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Bar Plot of Decade-wise Defense Budget

# %%
mil_ex_bp_plot_BRI = mil_ex_bp[(mil_ex_bp['Country Code'].isin(['BRA', 'RUS', 'IND', 'CHN', 'ZAF']))]
#mil_ex_bp_plot

fig, ax = plt.subplots(figsize = (12, 8))

ax.bar(np.arange(len(mil_ex_bp_plot_BRI['Country Code'])), mil_ex_bp_plot_BRI['60s']/10**9, 0.2, label = "60s")
ax.bar(np.arange(len(mil_ex_bp_plot_BRI['Country Code'])) + 0.1, mil_ex_bp_plot_BRI['70s']/10**9, 0.2, label = "70s")
ax.bar(np.arange(len(mil_ex_bp_plot_BRI['Country Code'])) + 0.2, mil_ex_bp_plot_BRI['80s']/10**9, 0.2, label = "80s")
ax.bar(np.arange(len(mil_ex_bp_plot_BRI['Country Code'])) + 0.3, mil_ex_bp_plot_BRI['90s']/10**9, 0.2, label = "90s")
ax.bar(np.arange(len(mil_ex_bp_plot_BRI['Country Code'])) + 0.4, mil_ex_bp_plot_BRI['00s']/10**9, 0.2, label = "00s")
ax.bar(np.arange(len(mil_ex_bp_plot_BRI['Country Code'])) + 0.5, mil_ex_bp_plot_BRI['10s']/10**9, 0.2, label = "10s")


ax.set_ylabel('Absolute Numbers (x10$\mathregular{^{9}}$ USD)', fontsize = 15)
ax.set_xticks(np.arange(len(mil_ex_bp_plot_BRI['Country Code']))+ 0.2)
ax.set_xticklabels(mil_ex_bp_plot_BRI['Country Code'])
ax.set_xlabel('Country', fontsize = 15)
ax.set_title('Decadal Spending on defense budget\n', fontsize = 25)

ax.legend()
ax.grid()
#plt.savefig("norm_case_test_bar.jpg")
#plt.show()

# %% [markdown]
# ## Plot of GDP

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, gdp.loc[gdp['Country Code'] == 'BRA', year_str].T/10**9, marker = '*', label = 'BRAZIL')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'RUS', year_str].T/10**9, marker = 'o', label = 'RUSSIA')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'IND', year_str].T/10**9, marker = 'X', label = 'INDIA')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'CHN', year_str].T/10**9, marker = '^', label = 'CHINA')
plt.plot(years, gdp.loc[gdp['Country Code'] == 'ZAF', year_str].T/10**9, marker = '+', label = 'SOUTH AFRICA')


plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Gross Domestic Product (x10$\mathregular{^{9}}$ USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Plot of GDP Per Capita

# %%
plt.figure(figsize = (15, 10))
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'BRA', year_str].T, marker = '*', label = 'BRAZIL')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'RUS', year_str].T, marker = 'o', label = 'RUSSIA')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'IND', year_str].T, marker = 'X', label = 'INDIA')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'CHN', year_str].T, marker = '^', label = 'CHINA')
plt.plot(years, gdp_pc.loc[gdp_pc['Country Code'] == 'ZAF', year_str].T, marker = '+', label = 'SOUTH AFRICA')

plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('Gross Domestic Product per capita(USD)\n', fontsize = 18)
plt.xticks(np.arange(1960, 2021, 5))
plt.show()

# %% [markdown]
# ## Plot of % of GDP spent on RnD

# %%
plt.figure(figsize = (15, 10))
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'BRA', year_str].T[36:], marker = '*', label = 'BRAZIL')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'RUS', year_str].T[36:], marker = 'o', label = 'RUSSIA')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'IND', year_str].T[36:], marker = 'X', label = 'INDIA')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'CHN', year_str].T[36:], marker = '^', label = 'CHINA')
plt.plot(years[36:], RnD_ex.loc[RnD_ex['Country Code'] == 'ZAF', year_str].T[36:], marker = '^', label = 'SOUTH AFRICA')


plt.grid()
plt.legend()
plt.xlabel("\nYears", fontsize = 18)
plt.ylabel('% of GDP spent on Research & Development\n', fontsize = 18)

plt.xticks(np.arange(1995, 2021, 3))
plt.show()

# %% [markdown]
# ## Bar Plot for Per Capita Income and % of GDP Spent on Defense and RnD

# %%
plt.figure(figsize = (24, 10))

plt.subplot(1,3, 1)
plt.pie(gdp_pc_BRI['sum_10_yrs']/10, labels = gdp_pc_BRI['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("Average GDP Per Capita\n Members of BRICS", fontsize = 21)

#plt.savefig("tot_pie.jpg")

plt.subplot(1, 3, 2)
plt.pie(df_gdp_BRI['sum_10_yrs'], labels = df_gdp_BRI['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("% of GDP spent on Defense by\n Members of BRICS", fontsize = 21)

#plt.savefig("tot_pie.jpg")


plt.subplot(1, 3, 3)
plt.pie(RnD_BRI['sum_10_yrs']/10, labels = RnD_BRI['Country Code'], autopct = "%0.2f")
#plt.legend()
plt.title("Average % Spending on RnD for \nmembers of BRICS", fontsize = 21)
plt.show()
#plt.savefig("tot_pie.jpg")

# %% [markdown]
# # References

# %% [markdown]
# Data taken from following World Bank studies:
#
# MILITARY EXPENDITURE:
# https://data.worldbank.org/indicator/MS.MIL.XPND.GD.ZS?view=map&year=2020
#
# COUNTRYWISE GROSS DOMESTIC PRODUCT:
# https://data.worldbank.org/indicator/NY.GDP.MKTP.CD
#
# RESEARCH AND DEVELOPMENT SPENDING:
# https://data.worldbank.org/indicator/GB.XPD.RSDV.GD.ZS?end=2018&most_recent_year_desc=false&start=2018&type=shaded&view=map
#
# SPENDING ON DEFENSE:
# https://data.worldbank.org/indicator/MS.MIL.XPND.GD.ZS?view=map&year=2020
#
# COUNTRYWISE PER CAPITA GDP:
# https://data.worldbank.org/indicator/NY.GDP.PCAP.CD
